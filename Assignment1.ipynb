# %% [markdown]
# # Install Power BI Desktop and share the final screenshot of the report view page which appears when power desktop starts.

# %% [markdown]
# ![Default%20View.jpg](attachment:Default%20View.jpg)

# %% [markdown]
# # Prepare a document and with the following screenshot

# %% [markdown]
# # Report View

# %% [markdown]
# ![Report%20View.jpg](attachment:Report%20View.jpg)

# %% [markdown]
# # Data View

# %% [markdown]
# ![Data%20View.jpg](attachment:Data%20View.jpg)

# %% [markdown]
# # Model View

# %% [markdown]
# ![Model%20View.jpg](attachment:Model%20View.jpg)

# %% [markdown]
# # Power Query Editor

# %% [markdown]
# ![Power%20Query%20Editor.jpg](attachment:Power%20Query%20Editor.jpg)

# %% [markdown]
# # Advanced Editor

# %% [markdown]
# ![Advanced%20Editor.jpg](attachment:Advanced%20Editor.jpg)

# %% [markdown]
# # Prepare a document with details of the following along with their price

# %% [markdown]
# ![Doc1.jpg](attachment:Doc1.jpg)

# %% [markdown]
# ![Doc2.jpg](attachment:Doc2.jpg)
